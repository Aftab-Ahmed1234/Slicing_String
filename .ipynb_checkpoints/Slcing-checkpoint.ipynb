# %%
b="Aftab Ahmed"
print(b[2:7])
# Out:
# tab A

# %%
b="Aftab Ahmed"
print(b[:5])
# Out:
# Aftab

# %%
b="Aftab Ahmed"
print(b[2:])
# Out:
# tab Ahmed

# %%
b="Aftab Ahmed"
print(b[-5:-3])
# Out:
# Ah
